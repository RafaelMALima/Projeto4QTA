# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IQA import *

# %%
df_4500_2012_2017 = pd.read_excel("PINH04500_2012_2017.xlsx")
df_4500_2017_2022 = pd.read_excel("PINH04500_2017_2022.xlsx")
df_4900_2012_2017 = pd.read_excel("PINH04900_2012_2017.xlsx")

# %%
df_4500_2012_2017.head()
# Out:
#    Período DE Período ATE  Cod_Interaguas    Tipo Rede            UGRHI  \
# 0  08/11/2017  08/11/2022            1784  Rede Básica  06 - ALTO TIÊTE
# 1  08/11/2017  08/11/2022            1784  Rede Básica  06 - ALTO TIÊTE
# 2  08/11/2017  08/11/2022            1784  Rede Básica  06 - ALTO TIÊTE
# 3  08/11/2017  08/11/2022            1784  Rede Básica  06 - ALTO TIÊTE
# 4  08/11/2017  08/11/2022            1784  Rede Básica  06 - ALTO TIÊTE
#
#   Código Ponto Status Ponto Data Coleta Hora Coleta            Parametro  ...  \
# 0    PINH04500        Ativo  29/11/2017       10:00                   pH  ...
# 1    PINH04500        Ativo  23/01/2018       10:25                   pH  ...
# 2    PINH04500        Ativo  29/11/2017       10:00  Temperatura da Água  ...
# 3    PINH04500        Ativo  23/01/2018       10:25  Temperatura da Água  ...
# 4    PINH04500        Ativo  29/11/2017       10:00    Temperatura do Ar  ...
#
# ...

# %%
qs1 = [Coliformes(610000),pH(7.14),DBO(80),NTotal(35.6),PTotal(2.13),Temp(22.8-24.5),Turbidez(45.9),ResTotal(262),O2(81)]
qs2 = [Coliformes(340000),pH(7.07),DBO(76),NTotal(14.5),PTotal(0.97),Temp(18.8-17.5),Turbidez(32.7),ResTotal(228),O2(180)]
qs3 = [Coliformes(750000),pH(7.12),DBO(54),NTotal(28.5),PTotal(2.41),Temp(21.5-22),Turbidez(19.6),ResTotal(328),O2(21)]
qs4 = [Coliformes(680000),pH(7.12),DBO(34),NTotal(13.6),PTotal(1.4),Temp(18.9-17.9),Turbidez(61.7),ResTotal(206),O2(39)]
qs5 = [Coliformes(840000),pH(7.19),DBO(82),NTotal(21.4),PTotal(2.1),Temp(20.32-19.1),Turbidez(71.2),ResTotal(304),O2(62)]
qs6 = [Coliformes(400000),pH(6.86),DBO(48),NTotal(26.5),PTotal(2.48),Temp(22.1-22.4),Turbidez(42),ResTotal(282),O2(46)]
qs7 = [Coliformes(1300000),pH(6.91),DBO(40),NTotal(20.7),PTotal(1.7),Temp(0.1),Turbidez(30.2),ResTotal(272),O2(199)]
qs8 = [Coliformes(2100000),pH(7.3),DBO(36.25),NTotal(20.8),PTotal(1),Temp(3.3),Turbidez(27.7),ResTotal(250),O2(59)]
qs9 = [Coliformes(8800),pH(6),DBO(30),NTotal(6.125),PTotal(20.6),Temp(-5),Turbidez(69.3),ResTotal(152.9),O2(78)]


qss = [qs1,qs2,qs3,qs4,qs5,qs6,qs7,qs8,qs9]





for i in range (len(qss)):
    print(f"IQA {i+1} = {IQA(qss[i]):.2f}")
    plt.plot(i,IQA(qss[i]),'o-',color='red')

plt.show()
# Out:
# IQA 1 = 24.90
# IQA 2 = 26.49
# IQA 3 = 19.31
# IQA 4 = 23.32
# IQA 5 = 24.16
# IQA 6 = 22.25
# IQA 7 = 24.73
# IQA 8 = 25.87
# IQA 9 = 21.37
